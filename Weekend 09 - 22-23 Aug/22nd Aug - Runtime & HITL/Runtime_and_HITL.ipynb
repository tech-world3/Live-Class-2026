# %% [markdown]
# # Runtime

# %%
# !pip install -U "langchain>=1.3.14"
# Out:
# Requirement already satisfied: langchain>=1.3.14 in /usr/local/lib/python3.13/dist-packages (1.3.15)
# Collecting langchain>=1.3.14
#   Downloading langchain-1.3.16-py3-none-any.whl.metadata (6.1 kB)
# Collecting langchain-core<2.0.0,>=1.6.0 (from langchain>=1.3.14)
#   Downloading langchain_core-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in /usr/local/lib/python3.13/dist-packages (from langchain>=1.3.14) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain>=1.3.14) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (0.11.0)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (0.17.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (4.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain>=1.3.14) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain>=1.3.14) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain>=1.3.14) (0.4.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.13/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.13/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (3.12.0)
# Requirement already satisfied: websockets<16,>=14 in /usr/local/lib/python3.13/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain>=1.3.14) (15.0.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (2.32.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain>=1.3.14) (2.5.0)
# Downloading langchain-1.3.16-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 3.1 MB/s eta 0:00:00
# Downloading langchain_core-1.6.0-py3-none-any.whl (570 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.0/570.0 kB 13.7 MB/s eta 0:00:00
# Installing collected packages: langchain-core, langchain
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.5.5
#     Uninstalling langchain-core-1.5.5:
#       Successfully uninstalled langchain-core-1.5.5
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.15
#     Uninstalling langchain-1.3.15:
#       Successfully uninstalled langchain-1.3.15
# Successfully installed langchain-1.3.16 langchain-core-1.6.0

# %%
# !pip install  langchain-openai langchain-community langgraph python-dotenv langchain-mcp-adapters langchain-chroma chromadb pypdf
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-1.6.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langgraph in /usr/local/lib/python3.13/dist-packages (1.2.11)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.13/dist-packages (1.2.3)
# Collecting langchain-mcp-adapters
#   Downloading langchain_mcp_adapters-0.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting langchain-chroma
#   Downloading langchain_chroma-1.1.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting chromadb
#   Downloading chromadb-1.5.9-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting pypdf
#   Downloading pypdf-6.16.1-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: certifi>=2024.6.2 in /usr/local/lib/python3.13/dist-packages (from langchain-openai) (2026.7.22)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from langchain-openai) (1.6.0)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in /usr/local/lib/python3.13/dist-packages (from langchain-openai) (2.54.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-openai) (0.14.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (3.14.3)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain-community)
#   Downloading langchain_classic-1.0.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (0.11.0)
# Requirement already satisfied: numpy>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.1.3)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.15.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (6.0.3)
# Collecting requests<3.0.0,>=2.32.5 (from langchain-community)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (2.0.52)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from langgraph) (0.4.2)
# Requirement already satisfied: pydantic>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langgraph) (2.13.4)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from langgraph) (4.0.1)
# Collecting mcp<2.0.0,>=1.24.0 (from langchain-mcp-adapters)
#   Downloading mcp-1.29.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from langchain-mcp-adapters) (4.16.0)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.5.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.5.0-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.52.3)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.29.0-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (1.42.1)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.44.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (1.42.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.13/dist-packages (from chromadb) (0.22.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (4.67.3)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (1.83.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (0.27.1)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-36.0.3-py2.py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.13/dist-packages (from chromadb) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.13/dist-packages (from chromadb) (3.12.0)
# Requirement already satisfied: httpx>=0.27.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.13/dist-packages (from chromadb) (4.26.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.13/dist-packages (from build>=1.0.3->chromadb) (26.3)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx>=0.27.0->chromadb) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx>=0.27.0->chromadb) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=4.19.0->chromadb) (2026.6.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /usr/local/lib/python3.13/dist-packages (from kubernetes>=28.1.0->chromadb) (2.5.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain-community)
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain-openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain-openai) (0.0.18)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain-openai) (0.17.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.13/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: websockets<16,>=14 in /usr/local/lib/python3.13/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/lib/python3.13/dist-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (2.13.0)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.13/dist-packages (from mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (0.0.32)
# Collecting sse-starlette>=1.6.1 (from mcp<2.0.0,>=1.24.0->langchain-mcp-adapters)
#   Downloading sse_starlette-3.4.8-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: starlette>=0.27 in /usr/local/lib/python3.13/dist-packages (from mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (1.6.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in /usr/local/lib/python3.13/dist-packages (from mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (0.4.4)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.13/dist-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in /usr/local/lib/python3.13/dist-packages (from onnxruntime>=1.14.1->chromadb) (5.29.6)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.13/dist-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.13/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.44.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.44.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.44.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.44.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.44.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.44.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-semantic-conventions==0.65b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.7.4->langgraph) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.7.4->langgraph) (2.46.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=10.11.0->chromadb) (2.21.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.13/dist-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.5)
# Requirement already satisfied: regex in /usr/local/lib/python3.13/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.13/dist-packages (from tokenizers>=0.13.2->chromadb) (1.27.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer>=0.9.0->chromadb) (0.0.5)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.13/dist-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb) (8.4.2)
# Requirement already satisfied: httptools>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.13/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.32.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.6.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain-openai) (3.1.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.13/dist-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (50.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (2.1.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.24.0->langchain-mcp-adapters) (3.0)
# Downloading langchain_openai-1.6.0-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.1/125.1 kB 9.0 MB/s eta 0:00:00
# Downloading langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 60.4 MB/s eta 0:00:00
# Downloading langchain_mcp_adapters-0.3.2-py3-none-any.whl (28 kB)
# Downloading langchain_chroma-1.1.0-py3-none-any.whl (12 kB)
# Downloading chromadb-1.5.9-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 70.5 MB/s eta 0:00:00
# Downloading pypdf-6.16.1-py3-none-any.whl (382 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 382.9/382.9 kB 25.8 MB/s eta 0:00:00
# Downloading bcrypt-5.0.0-cp39-abi3-manylinux_2_34_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 19.1 MB/s eta 0:00:00
# Downloading build-1.5.0-py3-none-any.whl (26 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading kubernetes-36.0.3-py2.py3-none-any.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 105.6 MB/s eta 0:00:00
# Downloading langchain_classic-1.0.8-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 47.3 MB/s eta 0:00:00
# Downloading mcp-1.29.0-py3-none-any.whl (223 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.4/223.4 kB 13.3 MB/s eta 0:00:00
# Downloading onnxruntime-1.29.0-cp313-cp313-manylinux_2_28_x86_64.whl (23.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 65.9 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.44.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.44.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_proto-1.44.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.7 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.44.0-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 9.6 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.44.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.4 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 16.3 MB/s eta 0:00:00
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pybase64-1.5.0-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.7/95.7 kB 7.3 MB/s eta 0:00:00
# Downloading pydantic_settings-2.15.0-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 4.7 MB/s eta 0:00:00
# Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.2 MB/s eta 0:00:00
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.9 MB/s eta 0:00:00
# Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Downloading sse_starlette-3.4.8-py3-none-any.whl (16 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Installing collected packages: pypika, durationpy, requests, pyproject_hooks, pypdf, pybase64, overrides, opentelemetry-proto, opentelemetry-api, onnxruntime, importlib-resources, httpx-sse, bcrypt, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, build, sse-starlette, pydantic-settings, opentelemetry-sdk, kubernetes, opentelemetry-exporter-otlp-proto-grpc, mcp, langchain-text-splitters, langchain-openai, langchain-mcp-adapters, chromadb, langchain-classic, langchain-chroma, langchain-community
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.42.1
#     Uninstalling opentelemetry-api-1.42.1:
#       Successfully uninstalled opentelemetry-api-1.42.1
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.63b1
#     Uninstalling opentelemetry-semantic-conventions-0.63b1:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.63b1
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.42.1
#     Uninstalling opentelemetry-sdk-1.42.1:
#       Successfully uninstalled opentelemetry-sdk-1.42.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# google-adk 2.7.1 requires opentelemetry-api<=1.42.1,>=1.39, but you have opentelemetry-api 1.44.0 which is incompatible.
# google-adk 2.7.1 requires opentelemetry-sdk<=1.42.1,>=1.39, but you have opentelemetry-sdk 1.44.0 which is incompatible.
# Successfully installed bcrypt-5.0.0 build-1.5.0 chromadb-1.5.9 durationpy-0.10 httpx-sse-0.4.3 importlib-resources-7.1.0 kubernetes-36.0.3 langchain-chroma-1.1.0 langchain-classic-1.0.8 langchain-community-0.4.2 langchain-mcp-adapters-0.3.2 langchain-openai-1.6.0 langchain-text-splitters-1.1.2 mcp-1.29.0 onnxruntime-1.29.0 opentelemetry-api-1.44.0 opentelemetry-exporter-otlp-proto-common-1.44.0 opentelemetry-exporter-otlp-proto-grpc-1.44.0 opentelemetry-proto-1.44.0 opentelemetry-sdk-1.44.0 opentelemetry-semantic-conventions-0.65b0 overrides-7.7.0 pybase64-1.5.0 pydantic-settings-2.15.0 pypdf-6.16.1 pypika-0.51.1 pyproject_hooks-1.2.0 requests-2.34.2 sse-starlette-3.4.8

# %%
# !pip install langchain-anthropic
# Out:
# Collecting langchain-anthropic
#   Downloading langchain_anthropic-1.6.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting anthropic<1.0.0,>=0.120.0 (from langchain-anthropic)
#   Downloading anthropic-0.125.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from langchain-anthropic) (1.6.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain-anthropic) (2.13.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from anthropic<1.0.0,>=0.120.0->langchain-anthropic) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from anthropic<1.0.0,>=0.120.0->langchain-anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.13/dist-packages (from anthropic<1.0.0,>=0.120.0->langchain-anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from anthropic<1.0.0,>=0.120.0->langchain-anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.13/dist-packages (from anthropic<1.0.0,>=0.120.0->langchain-anthropic) (0.16.0)
# Requirement already satisfied: sniffio<2,>=1 in /usr/local/lib/python3.13/dist-packages (from anthropic<1.0.0,>=0.120.0->langchain-anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.13/dist-packages (from anthropic<1.0.0,>=0.120.0->langchain-anthropic) (4.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain-anthropic) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain-anthropic) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain-anthropic) (0.11.0)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain-anthropic) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain-anthropic) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain-anthropic) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain-anthropic) (0.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (0.4.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5,>=3.5.0->anthropic<1.0.0,>=0.120.0->langchain-anthropic) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.120.0->langchain-anthropic) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.120.0->langchain-anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic<1.0.0,>=0.120.0->langchain-anthropic) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain-anthropic) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-anthropic) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-anthropic) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-anthropic) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-anthropic) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-anthropic) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-anthropic) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-anthropic) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-anthropic) (2.5.0)
# Downloading langchain_anthropic-1.6.1-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.2/57.2 kB 4.3 MB/s eta 0:00:00
# Downloading anthropic-0.125.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 41.1 MB/s eta 0:00:00
# Installing collected packages: anthropic, langchain-anthropic
# Successfully installed anthropic-0.125.0 langchain-anthropic-1.6.1

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
from google.colab import userdata
os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model('openai:gpt-5-mini')
model.invoke('Hi')
print("Cinebot's Brain is connected")
# Out:
# Cinebot's Brain is connected

# %%
from langchain.chat_models import init_chat_model
from langchain.agents import create_agent, AgentState
from langchain_core.tools import tool
from langchain.tools import tool as tool_rt, ToolRuntime
from dataclasses import dataclass

# %%
@dataclass
class CineBotContext:
  user_name:str
  #geo_state:str # Delhi or Bangalore or Chennai

# %%
agent_with_context = create_agent(
    model="openai:gpt-5-mini",
    tools=[],
    context_schema=CineBotContext,   # declares the SHAPE of context this agent expects
)

# %%
result = agent_with_context.invoke(
    {"messages": [{"role": "user", "content": "What's my name?"}]},
    context=CineBotContext(user_name="Priya"),   # injected at invocation time
)

# %% [markdown]
# # Runtime Inside Tools : ToolRuntime

# %%
@dataclass
class CustomerContext:
  user_id:str

# %%
from langgraph.store.memory import InMemoryStore

loyalty_store=InMemoryStore()

# %%
@tool
def fetch_customer_preferences(runtime: ToolRuntime[CustomerContext])-> str:
  "Feth the customer's Saved Preferences from a long term Memory"
  user_id=runtime.context.user_id
  preferences = "No Preferences"

  if runtime.store:
    if memory := runtime.store.get(('users'),user_id):
      preferences = memory.value['preferences']

  return preferences

# %%
pref_agent = create_agent(
    model="openai:gpt-5-mini",
    tools=[fetch_customer_preferences],
    context_schema=CustomerContext,
    store=loyalty_store,
)

# %% [markdown]
# # MiddleWare

# %%
#NodeStyle ( Before_model, after_model)
# Wrap_style_hooks ( wrap_model_call)

# %% [markdown]
# # Node Style Hooks

# %%
from langchain.agents.middleware import before_model, after_model

# %%
@before_model
def log_before_model(a,b):
  pass

# %%
logged_agent = create_agent(model="openai:gpt-5-mini", tools=[fetch_customer_preferences], middleware=[log_before_model])

# %%
result = logged_agent.invoke({"messages": [("user", "Get user preferences")]})

# %% [markdown]
# # Wrap Style Hooks

# %%
from langchain.agents.middleware import wrap_model_call, ModelRequest, ModelResponse
from typing import Callable

# %%
@wrap_model_call
def dynamic_greeting_prompt(request: ModelRequest,handler: Callable[[ModelRequest], ModelResponse])->ModelResponse:
  response = handler(request)
  return response

# %%
wrap_style_agent = create_agent(
    model="openai:gpt-5-mini",
    tools=[],
    middleware=[dynamic_greeting_prompt],
    context_schema=CineBotContext,
)

# %%
result = wrap_style_agent.invoke(
    {"messages": [("user", "What should I call you, and who am I?")]},
    context=CineBotContext(user_name="Rohan"),
)

# %% [markdown]
# # Dynamic Prompting

# %%
from langchain.agents.middleware import dynamic_prompt

# %%
@dataclass
class ClaudeContext:
  user_specific_instructions: str

# %%
@dynamic_prompt
def personalize_the_prompt(request:ModelRequest):
  user_name = request.runtime.context.user_name
  return f"{Claude_Instructions} + {request.runtime.context.user_specific_instructions}"

# %%
@before_model
def auth_gate(state:AgentState,runtime:Runtime)-> dict|None:
  "Block Unauthenticated users"
  server = runtime.server_info
  if server is not None:
    raise ValueError("Unauthenticated User")

  print(f"[AUTH] Passed the check for user {runtime.context.user_name} and threadID {runtime.execution_info.thread_id}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2803/2327680417.py in <cell line: 0>()
#       1 @before_model
# ----> 2 def auth_gate(state:AgentState,runtime:Runtime)-> dict|None:
#       3   "Block Unauthenticated users"
#       4   server = runtime.server_info
#       5   if server is not None:
#
# NameError: name 'Runtime' is not defined

# %% [markdown]
# # Human in the Loop ( In Depth )

# %%
from langchain.chat_models import init_chat_model
from langchain.agents import create_agent
from langchain_core.tools import tool
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langgraph.checkpoint.memory import InMemorySaver
from langgraph.types import Command
model = init_chat_model("openai:gpt-5-mini")

# %%
from rich import print

# %%
@tool
def cancel_booking(booking_id: str,runtime:ToolRuntime) -> str:
    """Cancel an existing booking. Irreversible."""
    return f"Booking {booking_id} cancelled."

# %%
unguarded_agent = create_agent(model="openai:gpt-5-mini", tools=[cancel_booking])
result = unguarded_agent.invoke({"messages": [("user", "Cancel my booking BK1042")]})

# %%
print(result)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='Cancel my booking BK1042',
#             additional_kwargs={},
#             response_metadata={},
#             id='55662253-1f48-490a-885a-2420f840f369'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 154,
#                     'prompt_tokens': 134,
#                     'total_tokens': 288,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 128,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-mini-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-EFXwcD74f67ALpmrV3loAyJKrTgRz',
#                 'service_tier': 'default',
#                 'finish_reason': 'tool_calls',
#                 'logprobs': None
#             },
#             id='lc_run--01a027cc-84c5-7853-8e13-48799c06d04e-0',
#             tool_calls=[
#                 {
#                     'name': 'cancel_booking',
#                     'args': {'booking_id': 'BK1042'},
#                     'id': 'call_nPYwKSLt1EGN4NnLhqUp213w',
#                     'type': 'tool_call'
#                 }
#             ],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 134,
#                 'output_tokens': 154,
#                 'total_tokens': 288,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 128}
#             }
#         ),
#         ToolMessage(
#             content='Booking BK1042 cancelled.',
#             name='cancel_booking',
#             id='5f79f1bc-b0a7-49c8-b7bf-cdc93824165e',
#             tool_call_id='call_nPYwKSLt1EGN4NnLhqUp213w'
#         ),
#         AIMessage(
#             content='Done — your booking BK1042 has been cancelled.',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 14,
#                     'prompt_tokens': 171,
#                     'total_tokens': 185,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 0,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-mini-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-EFXwelyIkGCz1DMAKdF3uun8KcW2A',
#                 'service_tier': 'default',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--01a027cc-8ed1-72c0-b4bd-f49dfce6299f-0',
#             tool_calls=[],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 171,
#                 'output_tokens': 14,
#                 'total_tokens': 185,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 0}
#             }
#         )
#     ]
# }

# %%
result = unguarded_agent.invoke({"messages": [("user", "Hi I am Mayank")]})

# %%
print(result)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='Hi I am Mayank',
#             additional_kwargs={},
#             response_metadata={},
#             id='2d8c4ec4-dbfb-460c-9cff-2d10ed0d2302'
#         ),
#         AIMessage(
#             content='Hi Mayank — nice to meet you. How can I help you today? (I can answer questions, draft or edit
# text, help with planning, check or cancel bookings, run calculations, or anything else you need.)',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 118,
#                     'prompt_tokens': 133,
#                     'total_tokens': 251,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 64,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-mini-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-EFXyVmAKfEkaUBgG7h1cKWJXl1kuM',
#                 'service_tier': 'default',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--01a027ce-4dd7-7592-898c-ffde6540f6d3-0',
#             tool_calls=[],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 133,
#                 'output_tokens': 118,
#                 'total_tokens': 251,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 64}
#             }
#         )
#     ]
# }

# %%
result = unguarded_agent.invoke({"messages": [("user", "Who am I?")]})

# %%
print(result)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='Who am I?',
#             additional_kwargs={},
#             response_metadata={},
#             id='3f827588-023f-4145-90cf-0ab3751ade5e'
#         ),
#         AIMessage(
#             content='I can’t read your mind or see your identity from here — but I can help you discover or
# describe who you are. Do you mean it philosophically (your purpose), practically (your roles, job, personality), or
# playfully (a riddle)?\n\nChoose one, or pick from these options and I’ll proceed:\n\n- Give me some facts (age,
# job, interests, goals) and I’ll write a clear “Who you are” summary.\n- I’ll ask a short set of reflective
# questions and synthesize your answers into a profile.\n- I can run a quick personality-style quiz (Big Five / brief
# Enneagram-style).\n- I can give exercises to explore values, strengths, and purpose.\n- I can answer creatively
# (poem, short story, or imaginative “you are”).\n\nIf you want to start right now, answer any or all of these four
# quick prompts and I’ll make a short profile from them:\n\n1) Three roles you currently fill (e.g., parent, student,
# designer).  \n2) Three strengths or things others compliment you about.  \n3) Three values that matter most to you
# (e.g., honesty, freedom, learning).  \n4) One thing that excites you and one thing that drains you.\n\nReply
# however you like and I’ll take it from there.',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 596,
#                     'prompt_tokens': 132,
#                     'total_tokens': 728,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 320,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-mini-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-EFY343Nb4t82ydG2fN5u44s5HTxde',
#                 'service_tier': 'default',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--01a027d2-9f57-7681-bc4e-7cac3d97a346-0',
#             tool_calls=[],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 132,
#                 'output_tokens': 596,
#                 'total_tokens': 728,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 320}
#             }
#         )
#     ]
# }

# %%
result.interrupts
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2803/2453987477.py in <cell line: 0>()
# ----> 1 result.interrupts
#
# AttributeError: 'dict' object has no attribute 'interrupts'

# %%
@tool
def send_booking_confirmation(booking_id: str, email: str) -> str:
    """Send a booking confirmation email. Safe, no approval needed."""
    return f"Confirmation for {booking_id} sent to {email}."

# %%
guarded_agent = create_agent(
    model="openai:gpt-5-mini",
    tools=[cancel_booking, send_booking_confirmation],
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "cancel_booking": True,               # all four decisions allowed (default config)
                "send_booking_confirmation": False,    # safe operation, auto-approved, never pauses
            },
            description_prefix="CineBot action pending your approval",
        ),
    ],
    checkpointer=InMemorySaver(),   # REQUIRED -- HITL needs to pause and later resume
)

# %%
config = {"configurable": {"thread_id": "hitl-demo-111"}}

# %%
result = guarded_agent.invoke(
    {"messages": [("user", "Cancel booking BK1042")]},
    config=config,
    version="v2",   # the current, recommended invoke pattern for reading interrupts
)

# %%
print(result)
# Out:
# GraphOutput(
#     value={
#         'messages': [
#             HumanMessage(
#                 content='Cancel booking BK1042',
#                 additional_kwargs={},
#                 response_metadata={},
#                 id='ac053d4f-3c00-4ae5-b7b2-fe9b24459dce'
#             ),
#             AIMessage(
#                 content='',
#                 additional_kwargs={'refusal': None},
#                 response_metadata={
#                     'token_usage': {
#                         'completion_tokens': 90,
#                         'prompt_tokens': 165,
#                         'total_tokens': 255,
#                         'completion_tokens_details': {
#                             'accepted_prediction_tokens': 0,
#                             'audio_tokens': 0,
#                             'reasoning_tokens': 64,
#                             'rejected_prediction_tokens': 0
#                         },
#                         'prompt_tokens_details': {
#                             'audio_tokens': 0,
#                             'cache_write_tokens': None,
#                             'cached_tokens': 0
#                         }
#                     },
#                     'model_provider': 'openai',
#                     'model_name': 'gpt-5-mini-2025-08-07',
#                     'system_fingerprint': None,
#                     'id': 'chatcmpl-EFY8AXHkIf6N8n9KJih4vnczeiwxj',
#                     'service_tier': 'default',
#                     'finish_reason': 'tool_calls',
#                     'logprobs': None
#                 },
#                 id='lc_run--01a027d7-7311-7c22-95c1-0965be61c893-0',
#                 tool_calls=[
#                     {
#                         'name': 'cancel_booking',
#                         'args': {'booking_id': 'BK1042'},
#                         'id': 'call_8NLujgz6NCjOtIgp0Cjdn1LF',
#                         'type': 'tool_call'
#                     }
#                 ],
#                 invalid_tool_calls=[],
#                 usage_metadata={
#                     'input_tokens': 165,
#                     'output_tokens': 90,
#                     'total_tokens': 255,
#                     'input_token_details': {'audio': 0, 'cache_read': 0},
#                     'output_token_details': {'audio': 0, 'reasoning': 64}
#                 }
#             )
#         ]
#     },
#     interrupts=(
#         Interrupt(
#             value={
#                 'action_requests': [
#                     {
#                         'name': 'cancel_booking',
#                         'args': {'booking_id': 'BK1042'},
#                         'description': "CineBot action pending your approval\n\nTool: cancel_booking\nArgs:
# {'booking_id': 'BK1042'}"
#                     }
#                 ],
#                 'review_configs': [
#                     {
#                         'action_name': 'cancel_booking',
#                         'allowed_decisions': ['approve', 'edit', 'reject', 'respond']
#                     }
#                 ]
#             },
#             id='f5d2637c9f17328db7b63e25718eaef1'
#         ),
#     )
# )

# %%
result.interrupts
# Out:
# (Interrupt(value={'action_requests': [{'name': 'cancel_booking', 'args': {'booking_id': 'BK1042'}, 'description': "CineBot action pending your approval\n\nTool: cancel_booking\nArgs: {'booking_id': 'BK1042'}"}], 'review_configs': [{'action_name': 'cancel_booking', 'allowed_decisions': ['approve', 'edit', 'reject', 'respond']}]}, id='f5d2637c9f17328db7b63e25718eaef1'),)

# %% [markdown]
# # Command

# %%
resumed = guarded_agent.invoke(
    Command(
        resume={"decisions": [{"type": "approve"}]}  # or "reject"
    ),
    config=config, # Same thread ID to resume the paused conversation
    version="v2",
)

# %%
print(resumed)
# Out:
# GraphOutput(
#     value={
#         'messages': [
#             HumanMessage(
#                 content='Cancel booking BK1042',
#                 additional_kwargs={},
#                 response_metadata={},
#                 id='ac053d4f-3c00-4ae5-b7b2-fe9b24459dce'
#             ),
#             AIMessage(
#                 content='',
#                 additional_kwargs={'refusal': None},
#                 response_metadata={
#                     'token_usage': {
#                         'completion_tokens': 90,
#                         'prompt_tokens': 165,
#                         'total_tokens': 255,
#                         'completion_tokens_details': {
#                             'accepted_prediction_tokens': 0,
#                             'audio_tokens': 0,
#                             'reasoning_tokens': 64,
#                             'rejected_prediction_tokens': 0
#                         },
#                         'prompt_tokens_details': {
#                             'audio_tokens': 0,
#                             'cache_write_tokens': None,
#                             'cached_tokens': 0
#                         }
#                     },
#                     'model_provider': 'openai',
#                     'model_name': 'gpt-5-mini-2025-08-07',
#                     'system_fingerprint': None,
#                     'id': 'chatcmpl-EFY8AXHkIf6N8n9KJih4vnczeiwxj',
#                     'service_tier': 'default',
#                     'finish_reason': 'tool_calls',
#                     'logprobs': None
#                 },
#                 id='lc_run--01a027d7-7311-7c22-95c1-0965be61c893-0',
#                 tool_calls=[
#                     {
#                         'name': 'cancel_booking',
#                         'args': {'booking_id': 'BK1042'},
#                         'id': 'call_8NLujgz6NCjOtIgp0Cjdn1LF',
#                         'type': 'tool_call'
#                     }
#                 ],
#                 invalid_tool_calls=[],
#                 usage_metadata={
#                     'input_tokens': 165,
#                     'output_tokens': 90,
#                     'total_tokens': 255,
#                     'input_token_details': {'audio': 0, 'cache_read': 0},
#                     'output_token_details': {'audio': 0, 'reasoning': 64}
#                 }
#             ),
#             ToolMessage(
#                 content='Booking BK1042 cancelled.',
#                 name='cancel_booking',
#                 id='6c88e4f0-f17d-470b-bfa5-8db965806922',
#                 tool_call_id='call_8NLujgz6NCjOtIgp0Cjdn1LF'
#             ),
#             AIMessage(
#                 content='Done — booking BK1042 has been cancelled. Would you like a confirmation email sent to you?
# If so, please provide the email address.',
#                 additional_kwargs={'refusal': None},
#                 response_metadata={
#                     'token_usage': {
#                         'completion_tokens': 32,
#                         'prompt_tokens': 202,
#                         'total_tokens': 234,
#                         'completion_tokens_details': {
#                             'accepted_prediction_tokens': 0,
#                             'audio_tokens': 0,
#                             'reasoning_tokens': 0,
#                             'rejected_prediction_tokens': 0
#                         },
#                         'prompt_tokens_details': {
#                             'audio_tokens': 0,
#                             'cache_write_tokens': None,
#                             'cached_tokens': 0
#                         }
#                     },
#                     'model_provider': 'openai',
#                     'model_name': 'gpt-5-mini-2025-08-07',
#                     'system_fingerprint': None,
#                     'id': 'chatcmpl-EFY8rpSAToMFKX2zPuI0yhoNzxx1e',
#                     'service_tier': 'default',
#                     'finish_reason': 'stop',
#                     'logprobs': None
#                 },
#                 id='lc_run--01a027d8-1af8-7d42-b308-2b7265d0cf62-0',
#                 tool_calls=[],
#                 invalid_tool_calls=[],
#                 usage_metadata={
#                     'input_tokens': 202,
#                     'output_tokens': 32,
#                     'total_tokens': 234,
#                     'input_token_details': {'audio': 0, 'cache_read': 0},
#                     'output_token_details': {'audio': 0, 'reasoning': 0}
#                 }
#             )
#         ]
#     },
#     interrupts=()
# )

# %% [markdown]
# # Edit

# %%
resumed_edit = guarded_agent.invoke(
    Command(resume={"decisions": [{
        "type": "edit",
        "edited_action": {"name": "cancel_booking", "args": {"booking_id": "BK1042"}},
    }]}),
    config=config2, version="v2",
)

# %%
config3 = {"configurable": {"thread_id": "hitl-demo-3"}}
guarded_agent.invoke({"messages": [("user", "Cancel booking BK1042")]}, config=config3, version="v2")

resumed_reject = guarded_agent.invoke(
    Command(resume={"decisions": [{
        "type": "reject",
        "message": "Cancellations require manager sign-off first. Ask the customer to call support.",
    }]}),
    config=config3, version="v2",
)

# %%
print(resumed_reject.value["messages"][-1].content)
# Out:
# I can’t cancel BK1042 from here — cancellations require manager sign-off. Please call support so a manager can
# approve the cancellation. When you contact them, have this ready:
#
# - Booking ID: BK1042
# - Name on the booking
# - Booking date/time
# - Reason for cancellation
# - Preferred outcome (refund, credit, reschedule)
# - Your contact phone/email
#
# Would you like me to:
# - Draft an email you can send to support, or
# - Prepare a short phone script for the call?
#
# Tell me which and any details (name, reason, preferred outcome) and I’ll draft it.

# %%
@tool
def ask_customer(question: str) -> str:
    """Ask the customer a clarifying question and wait for their reply."""
    return "placeholder -- never actually reached, respond intercepts this"

# %%
ask_agent = create_agent(
    model="openai:gpt-5-mini",
    tools=[ask_customer],
    middleware=[HumanInTheLoopMiddleware(interrupt_on={"ask_customer": {"allowed_decisions": ["respond"]}})],
    checkpointer=InMemorySaver(),
)

# %%
config_ask = {"configurable": {"thread_id": "hitl-demo-3"}}

# %%
ask_agent.invoke({"messages": [("user", "Cancel booking BK1042")]}, config=config_ask)
# Out:
# {'messages': [HumanMessage(content='Cancel booking BK1042', additional_kwargs={}, response_metadata={}, id='2eb1470f-9165-4e7c-90bc-a893b0a8bf03'),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 195, 'prompt_tokens': 136, 'total_tokens': 331, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-EFYIYMjF5JZbtvLKHR5z1CuhCGTEt', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--01a027e1-454d-74f3-bf1e-2257c2dd5070-0', tool_calls=[{'name': 'ask_customer', 'args': {'question': 'Do you want me to cancel booking BK1042 now? If yes, do you prefer a refund to the original payment method or a credit/voucher? (Also tell me if you need a cancellation reason or receipt emailed.)'}, 'id': 'call_BSl9fpBpNv4aYS8Ux6T1lwjW', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 136, 'output_tokens': 195, 'total_tokens': 331, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})],
#  '__interrupt__': [Interrupt(value={'action_requests': [{'name': 'ask_customer', 'args': {'question': 'Do you want me to cancel booking BK1042 now? If yes, do you prefer a refund to the original payment method or a credit/voucher? (Also tell me if you need a cancellation reason or receipt emailed.)'}, 'description': "Tool execution requires approval\n\nTool: ask_customer\nArgs: {'question': 'Do you want me to cancel booking BK1042 now? If yes, do you prefer a refund to the original payment method or a credit/voucher? (Also tell me if you need a cancellation reason or receipt emailed.)'}"}], 'review_configs': [{'action_name': 'ask_customer', 'allowed_decisions': ['respond']}]}, id='527686e03b60a051571e09a6edd41cea')]}

# %%
resumed_agent_respond = ask_agent.invoke(
    Command(resume={"decisions": [{
        "type": "respond",
        "message": "Its Booking BK1042, for the movie interstellar",
    }]}),
    config=config_ask
)

# %%
print(resumed_agent_respond)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='Cancel booking BK1042',
#             additional_kwargs={},
#             response_metadata={},
#             id='2eb1470f-9165-4e7c-90bc-a893b0a8bf03'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 195,
#                     'prompt_tokens': 136,
#                     'total_tokens': 331,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 128,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-mini-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-EFYIYMjF5JZbtvLKHR5z1CuhCGTEt',
#                 'service_tier': 'default',
#                 'finish_reason': 'tool_calls',
#                 'logprobs': None
#             },
#             id='lc_run--01a027e1-454d-74f3-bf1e-2257c2dd5070-0',
#             tool_calls=[
#                 {
#                     'name': 'ask_customer',
#                     'args': {
#                         'question': 'Do you want me to cancel booking BK1042 now? If yes, do you prefer a refund to
# the original payment method or a credit/voucher? (Also tell me if you need a cancellation reason or receipt
# emailed.)'
#                     },
#                     'id': 'call_BSl9fpBpNv4aYS8Ux6T1lwjW',
#                     'type': 'tool_call'
#                 }
#             ],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 136,
#                 'output_tokens': 195,
#                 'total_tokens': 331,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 128}
#             }
#         ),
#         ToolMessage(
#             content='Its Booking BK1042, for the movie interstellar',
#             name='ask_customer',
#             id='3fbfc258-de8f-48a5-91a1-38f824e47254',
#             tool_call_id='call_BSl9fpBpNv4aYS8Ux6T1lwjW'
#         ),
#         AIMessage(
#             content='Thanks — I can cancel booking BK1042 (Interstellar). A couple quick confirmations before I
# proceed:\n\n1) Cancel entire booking BK1042 (all tickets) — yes or no? If no, which seats/tickets to keep/cancel?
# \n2) Refund preference: refund to the original payment method, or issue a credit/voucher?  \n3) Do you want a
# cancellation receipt emailed? If yes, what email should I use (or confirm the one on your account)?  \n4) Any
# reason you want recorded for the cancellation (optional)?\n\nNote: cancellations may be subject to the cinema’s
# policy/fees and refunds can take 5–10 business days to appear on your card. Once you confirm the answers above I’ll
# proceed.',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 480,
#                     'prompt_tokens': 219,
#                     'total_tokens': 699,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 320,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-mini-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-EFYKqqAfZiOw1E2Ipv1AlupSzIHDp',
#                 'service_tier': 'default',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--01a027e3-72b6-74f2-8471-1bf6a667e0ca-0',
#             tool_calls=[],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 219,
#                 'output_tokens': 480,
#                 'total_tokens': 699,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 320}
#             }
#         )
#     ]
# }

# %% [markdown]
# # Conditional Interrupts

# %%
from langchain.agents.middleware import ToolCallRequest

@tool
def cancel_booking_priced(booking_id: str, amount: float) -> str:
    """Cancel a booking with a refund amount."""
    return f"Booking {booking_id} cancelled, ${amount:.2f} refunded."

# %%
ToolCallRequest
'''
    tool_call: ToolCall
    tool: BaseTool | None
    state: Any
    runtime: ToolRuntime
'''
# Out:
# langgraph.prebuilt.tool_node.ToolCallRequest

# %%
def is_large_refund(request: ToolCallRequest)-> bool:
  # amount = request.tool_call['args'].get('amount',0)
  # return amount >100
  return True

# %%
conditional_agent = create_agent(
    model="openai:gpt-5-mini",
    tools=[cancel_booking_priced],
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "cancel_booking_priced": {
                    "allowed_decisions": ["approve", "edit", "reject"],
                    "when": is_large_refund,
                },
            },
        ),
    ],
    checkpointer=InMemorySaver(),
)

# %%
config_small = {"configurable": {"thread_id": "small-refund"}}
r_small = conditional_agent.invoke(
    {"messages": [("user", "Cancel booking BK1001, refund $25")]}, config=config_small
)
print("Small refund, paused?", bool(r_small.interrupts))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2803/2476260335.py in <cell line: 0>()
#       3     {"messages": [("user", "Cancel booking BK1001, refund $25")]}, config=config_small
#       4 )
# ----> 5 print("Small refund, paused?", bool(r_small.interrupts))
#
# AttributeError: 'dict' object has no attribute 'interrupts'

# %%
print(r_small)
# Out:
# {
#     'messages': [
#         HumanMessage(
#             content='Cancel booking BK1001, refund $25',
#             additional_kwargs={},
#             response_metadata={},
#             id='e41cd2e6-7d68-4450-ab49-2e86075d1f30'
#         ),
#         AIMessage(
#             content='',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 96,
#                     'prompt_tokens': 142,
#                     'total_tokens': 238,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 64,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-mini-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-EFYbHYM6rEMPWeni4KvYpwaP5Hm7p',
#                 'service_tier': 'default',
#                 'finish_reason': 'tool_calls',
#                 'logprobs': None
#             },
#             id='lc_run--01a027f2-faa7-7e42-ba20-627632f79761-0',
#             tool_calls=[
#                 {
#                     'name': 'cancel_booking_priced',
#                     'args': {'booking_id': 'BK1001', 'amount': 25},
#                     'id': 'call_xJdPpiBwOHaB4mIBohgFWQ8L',
#                     'type': 'tool_call'
#                 }
#             ],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 142,
#                 'output_tokens': 96,
#                 'total_tokens': 238,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 64}
#             }
#         ),
#         ToolMessage(
#             content='Booking BK1001 cancelled, $25.00 refunded.',
#             name='cancel_booking_priced',
#             id='2bfad941-99fd-47e2-ad51-369096751ac4',
#             tool_call_id='call_xJdPpiBwOHaB4mIBohgFWQ8L'
#         ),
#         AIMessage(
#             content='Done — booking BK1001 has been cancelled and $25.00 refunded.',
#             additional_kwargs={'refusal': None},
#             response_metadata={
#                 'token_usage': {
#                     'completion_tokens': 19,
#                     'prompt_tokens': 193,
#                     'total_tokens': 212,
#                     'completion_tokens_details': {
#                         'accepted_prediction_tokens': 0,
#                         'audio_tokens': 0,
#                         'reasoning_tokens': 0,
#                         'rejected_prediction_tokens': 0
#                     },
#                     'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}
#                 },
#                 'model_provider': 'openai',
#                 'model_name': 'gpt-5-mini-2025-08-07',
#                 'system_fingerprint': None,
#                 'id': 'chatcmpl-EFYbJbakS60jNbvVoTxeN5aU35tZK',
#                 'service_tier': 'default',
#                 'finish_reason': 'stop',
#                 'logprobs': None
#             },
#             id='lc_run--01a027f3-061d-7a22-bd33-a424c552cde9-0',
#             tool_calls=[],
#             invalid_tool_calls=[],
#             usage_metadata={
#                 'input_tokens': 193,
#                 'output_tokens': 19,
#                 'total_tokens': 212,
#                 'input_token_details': {'audio': 0, 'cache_read': 0},
#                 'output_token_details': {'audio': 0, 'reasoning': 0}
#             }
#         )
#     ]
# }

# %%
config_large = {"configurable": {"thread_id": "large-refund"}}
r_large = conditional_agent.invoke(
    {"messages": [("user", "Cancel booking BK1002, refund $500")]}, config=config_large, version="v2",
)
print("Large refund, paused?", bool(r_large.interrupts))
# Out:
# Large refund, paused? True

# %%
print(r_large)
# Out:
# GraphOutput(
#     value={
#         'messages': [
#             HumanMessage(
#                 content='Cancel booking BK1002, refund $500',
#                 additional_kwargs={},
#                 response_metadata={},
#                 id='d45a2485-350b-4925-a953-af29d5ecb52d'
#             ),
#             AIMessage(
#                 content='',
#                 additional_kwargs={'refusal': None},
#                 response_metadata={
#                     'token_usage': {
#                         'completion_tokens': 160,
#                         'prompt_tokens': 142,
#                         'total_tokens': 302,
#                         'completion_tokens_details': {
#                             'accepted_prediction_tokens': 0,
#                             'audio_tokens': 0,
#                             'reasoning_tokens': 128,
#                             'rejected_prediction_tokens': 0
#                         },
#                         'prompt_tokens_details': {
#                             'audio_tokens': 0,
#                             'cache_write_tokens': None,
#                             'cached_tokens': 0
#                         }
#                     },
#                     'model_provider': 'openai',
#                     'model_name': 'gpt-5-mini-2025-08-07',
#                     'system_fingerprint': None,
#                     'id': 'chatcmpl-EFYbpC7xgpXg4TRp2F5JntHUudove',
#                     'service_tier': 'default',
#                     'finish_reason': 'tool_calls',
#                     'logprobs': None
#                 },
#                 id='lc_run--01a027f3-82af-7353-9eaa-20891f065f1e-0',
#                 tool_calls=[
#                     {
#                         'name': 'cancel_booking_priced',
#                         'args': {'booking_id': 'BK1002', 'amount': 500},
#                         'id': 'call_dyPmE5pRLXh3XARV29k8bq8M',
#                         'type': 'tool_call'
#                     }
#                 ],
#                 invalid_tool_calls=[],
#                 usage_metadata={
#                     'input_tokens': 142,
#                     'output_tokens': 160,
#                     'total_tokens': 302,
#                     'input_token_details': {'audio': 0, 'cache_read': 0},
#                     'output_token_details': {'audio': 0, 'reasoning': 128}
#                 }
#             )
#         ]
#     },
#     interrupts=(
#         Interrupt(
#             value={
#                 'action_requests': [
#                     {
#                         'name': 'cancel_booking_priced',
#                         'args': {'booking_id': 'BK1002', 'amount': 500},
#                         'description': "Tool execution requires approval\n\nTool: cancel_booking_priced\nArgs:
# {'booking_id': 'BK1002', 'amount': 500}"
#                     }
#                 ],
#                 'review_configs': [
#                     {'action_name': 'cancel_booking_priced', 'allowed_decisions': ['approve', 'edit', 'reject']}
#                 ]
#             },
#             id='f7ed358d30269add05ee8c182ef739af'
#         ),
#     )
# )

# %%
def run_interactive_hitl(agent, config):
    """A real, interactive HITL loop -- uses the CORRECTED edited_action format."""
    result = agent.invoke({"messages": [("user", "Cancel booking BK1042")]}, config=config, version="v2")
    if not result.interrupts:
        print("Nothing paused for review.")
        return

    print("CineBot wants to cancel booking BK1042. Choose a decision:")
    print("  1) approve")
    print("  2) edit     -- cancel a DIFFERENT booking ID instead")
    print("  3) reject")
    choice = input("Type 1, 2, or 3: ").strip()

    if choice == "1":
        decision = {"type": "approve"}
    elif choice == "2":
        new_id = input("Booking ID to cancel instead: ").strip()
        decision = {"type": "edit", "edited_action": {"name": "cancel_booking", "args": {"booking_id": new_id}}}
    elif choice == "3":
        reason = input("Reason: ").strip()
        decision = {"type": "reject", "message": reason}
    else:
        print("Not a valid choice.")
        return

    resumed = agent.invoke(Command(resume={"decisions": [decision]}), config=config, version="v2")
    print()
    print("Final:", resumed.value["messages"][-1].content)

run_interactive_hitl(guarded_agent, {"configurable": {"thread_id": "live-interactive-demo3"}})
# Out:
# CineBot wants to cancel booking BK1042. Choose a decision:
#   1) approve
#   2) edit     -- cancel a DIFFERENT booking ID instead
#   3) reject
# Type 1, 2, or 3: 1
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Final: Done — booking BK1042 has been cancelled. Would you like a confirmation email sent to the booking email on
# file (or a different address)?
